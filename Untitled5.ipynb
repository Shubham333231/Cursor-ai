# %% [markdown]
# <a href="https://colab.research.google.com/github/Shubham333231/Cursor-ai/blob/main/Untitled5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
for i in range (1,51):
  if i % 4 == 0:
    print(i)
# Out:
# 4
# 8
# 12
# 16
# 20
# 24
# 28
# 32
# 36
# 40
# 44
# 48

# %%
i = 1
count = 0

while i <= 100 :
  if i % 3 == 0:
      print(i)
      count = count + i

  i = i + 1

print(count)
# Out:
# 3
# 6
# 9
# 12
# 15
# 18
# 21
# 24
# 27
# 30
# 33
# 36
# 39
# 42
# 45
# 48
# 51
# 54
# 57
# 60
# 63
# 66
# 69
# 72
# 75
# 78
# 81
# 84
# 87
# 90
# 93
# 96
# 99
# 1683

# %%
count = 0
total = 0
for i in range (1,11):
  if i % 2 == 0:
    print(i)
    count = count + 1
    total = total + i

print("Even count:", count)
print("Even sum:", total)
# Out:
# 2
# 4
# 6
# 8
# 10
# Even count: 5
# Even sum: 30

# %%
i = 5832
reversed_num = int(str(i)[::-1])

print(reversed_num)
# Out:
# 2385

# %%
num = 12345
reversed_num = 0
while num > 0:
  digit = num % 10
  reversed_num = reversed_num * 10 + digit
  num = num // 10

# %%
user = int(input("Enter a number"))
total = 0
count = 0
while  num >= 0:
  digit = num % 10
  total = total + digit
  count = count + 1
  num = num // 10

print("Digit Sum:",total)
print("Digit count:", count)
# Out:
# Enter a number123

# %%
for i in range(1,60):
  if number
