# %% [markdown]
# <a href="https://colab.research.google.com/github/Shubham333231/Cursor-ai/blob/main/Day2masai.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
name = (input("Enter the name:"))
age = int(input("Enter the age:"))
branch = (input("Enter the branch:"))
cgpa = float(input("Enter the cgpa:"))

print("\n ---- Student Information ---")
print(f"Name:{name}")
print(f"Age:{age}")
print(f"Branch:{branch}")
print(f"CGPA:{cgpa}")
# Out:
# Enter the name:Shubham
# Enter the age:99
# Enter the branch:E&TC
# Enter the cgpa:9.9999
#
#  ---- Student Information ---
# Name:Shubham
# Age:99
# Branch:E&TC
# CGPA:9.9999

# %%
Celsius  = float(input("Enter the temperature in celsius:"))

farenheit = (Celsius* 9/5) + 32

print("temperature in Farenheit:",farenheit)
# Out:
# Enter the temperature in celsius:22
# temperature in Farenheit: 71.6

# %%
First_number = float(input("Enter the First number:"))
Second_number = float(input("Enter the Second number:"))

Addition = First_number + Second_number
Subtraction = First_number - Second_number
Multiplication = First_number * Second_number
Division = First_number / Second_number

print(f"Addition: {Addition}")
print(f"Subtraction: {Subtraction}")
print(f"Multiplication: {Multiplication}")
print(f"Division: {Division}")
# Out:
# Enter the First number:22
# Enter the Second number:44
# Addition: 66.0
# Subtraction: -22.0
# Multiplication: 968.0
# Division: 0.5

# %%
Num = int(input("Enter the number:"))

if Num % 2 == 0:
  print("Num is even number")

elif Num % 3 == 0:
  print("Num is odd number")

else:
  print("prime number")
# Out:
# Enter the number:1
# prime number

# %%
number = int(input("Enter the number:"))

for i in range(1,11):
  print(number, "x",i,"=",number*i)
# Out:
# Enter the number:7
# 7 x 1 = 7
# 7 x 2 = 14
# 7 x 3 = 21
# 7 x 4 = 28
# 7 x 5 = 35
# 7 x 6 = 42
# 7 x 7 = 49
# 7 x 8 = 56
# 7 x 9 = 63
# 7 x 10 = 70
