# %% [markdown]
# <a href="https://colab.research.google.com/github/Shubham333231/Cursor-ai/blob/main/day10masai.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Given a list of ints, return True if the array contains a 3 next to a 3 somewhere.

has_33([1, 3, 3]) → True
def check_33(nums):
  for i in range (0,len(nums)-1):
    if nums[i] == 3 and nums[i+1] == 3:
      return True
  return False

# %%
check_33([1,3,3])
# Out:
# True

# %%
#PAPER DOLL: Given a string, return a string where for every character in the original there are three characters
#paper_doll('Hello') --> 'HHHeeellllllooo'
def paper_doll(text):
  result = ""

  for char in text:
    result += char*3

  return result

# %%
paper_doll('Hello')
# Out:
# 'HHHeeellllllooo'

# %%
#BLACKJACK: Given three integers between 1 and 11, if their sum is less than or equal to 21, return their sum. If their sum exceeds 21 and there's an eleven, reduce the total sum by 10. Finally, if the sum (even after adjustment) exceeds 21, return 'BUST'
#blackjack(5,6,7) --> 18

def blackjack_check(a,b,c):
  if sum((a,b,c)) <= 21:
    return sum((a,b,c))
  elif 11 in (a,b,c) and sum((a,b,c)) <= 31:
    return sum((a,b,c)) - 10
  else:
    return 'BUST'

# %%
blackjack_check(10,9,2.5)
# Out:
# 'BUST'

# %%
#SUMMER OF '69: Return the sum of the numbers in the array, except ignore sections of numbers starting with a 6 and extending to the next 9 (every 6 will be followed by at least one 9). Return 0 for no numbers.
#ummer_69([1, 3, 5]) --> 9
#summer_69([4, 5, 6, 7, 8, 9]) --> 9
#summer_69([2, 1, 6, 9, 11]) --> 14def sum_return()

def summer_69(arr):
    total = 0
    ignore = False
    for num in arr:
        if num == 6:
            ignore = True
        elif num == 9:
            ignore = False
        elif not ignore:
            total += num
    return total

# %%
summer_69([4, 5, 6, 7, 8, 9])
# Out:
# 9

# %%
#Count digit without using len() in function

def count_digit(n):
  total = 0
  while n > 0:
    total = total + 1
    n = n // 10

  return total

print(count_digit(1234))
# Out:
# 4

# %%
#sum of even digits

def even_digit_sum(n):
  count = 0
  while n > 0:
    digit = n % 10

    if digit % 2 == 0:
      count = count + digit

    n = n // 10
    return count

print(even_digit_sum(1234))
# Out:
# 4

# %%
#take out the sum of even numbers

total = 0
for num in range(1,11):
  if num % 2 == 0:
    total = total + 1

print("Even Sum:", total)
# Out:
# Even Sum: 5

# %%
#write a function that return square of a number

def square_num(n):
    return n*n

# %%
square_num(2)
# Out:
# 4

# %%
square_num(5)
# Out:
# 25

# %%
#write a function is evem that returns true if the number is true else return false

def even_check(n):
  if  n % 2 == 0:
    return True
  else:
    return False

# %%
even_check(88)
# Out:
# True

# %%
even_check(98)
# Out:
# True

# %%
even_check(105)
# Out:
# False

# %%
#write a function that return the large num without using max()

def_check(a,b):
  if a > b:
    return "a is bigger"
  else:
    return b>a
# Out:
#   File "/tmp/ipykernel_467/3708187283.py", line 3
#     def_check(a,b):
#                   ^
# SyntaxError: invalid syntax

# %% [markdown]
# ### Corrected Function to Find the Larger Number

# %%
# Corrected function that returns the larger number without using max()
def find_larger_num(a, b):
  if a > b:
    return a
  else:
    return b

# %% [markdown]
# ### Demonstration of `find_larger_num`

# %%
print(f"The larger number between 10 and 5 is: {find_larger_num(10, 5)}")
print(f"The larger number between 3 and 7 is: {find_larger_num(3, 7)}")
print(f"The larger number between 8 and 8 is: {find_larger_num(8, 8)}")
# Out:
# The larger number between 10 and 5 is: 10
# The larger number between 3 and 7 is: 7
# The larger number between 8 and 8 is: 8

# %%
#write a function that return area of rectangle

def area_rect(a, b):
  return (a*b)

# %%
area_rect(5,3)
# Out:
# 15

# %%
#write a function check that prints wheater a number is positive,negative,zero

def check_num(n):
  if n > 0:
    return "Positve number"
  elif n < 0:
    return "Negative number"
  else:
    return "Zero"

print(f"The number is {check_num(10)}")
print(f"The number is {check_num(-5)}")
print(f"The number is {check_num(0)}")
# Out:
# The number is Positve number
# The number is Negative number
# The number is Zero

# %%
#write a function that return their sum of three numbers.

def add_sum(a , b , c):
    return a + b + c

print(add_sum(10 , 20 , 30))
# Out:
# 60

# %%
#write a function that return true if age is 18 or above

def check_age(n):
  if n >= 18:
    return "Eligible"
  else:
    return "Not Eligible"

print(f"You are {check_age(18)}")
print(f"You are {check_age(17.9)}")
# Out:
# You are Eligible
# You are Not Eligible

# %%
#write a function factorial(n) that calculates factorial using a loop.

def check_factorial(n):
  total = 1

  while n > 0:
    total = total * n
    n = n - 1
  return total

print(check_factorial(5))
# Out:
# 120

# %%
#write a function that returns the number of digits in an integer

def count_num(n):
  count = 0

  while n > 0:
    n = n // 10
    count += 1

  return count

print(count_num(12344))
# Out:
# 5

# %%
from string import digits
#write a function that reversed the number

def reversed_num(n):
  rev = 0


  while n > 0:
    digits = n % 10
    rev =  rev * 10 + digits
    n = n // 10
  return rev
print(reversed_num(5321))
# Out:
# 1235
