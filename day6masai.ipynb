# %% [markdown]
# <a href="https://colab.research.google.com/github/Shubham333231/Cursor-ai/blob/main/day6masai.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
count = 0
for i in range (1,101):
  if i % 7 == 0:
    print(i)
    count = count + 1

print("Count:",count)
# Out:
# 7
# 14
# 21
# 28
# 35
# 42
# 49
# 56
# 63
# 70
# 77
# 84
# 91
# 98
# Count: 14

# %%
number = int(input("Enter a number:"))

if number < 2:
  print("Not Prime")
else:
  prime = True
  for i in range(2, number):
    if number % i == 0:
      prime = False
      break
  if prime:
    print("Prime")
  else:
    print("Not Prime")
# Out:
# Enter a number:7
# Prime

# %%
number = int(input("Enter a number:"))
total = 0
while number > 0:
    digit = number % 10
    number // 10

print("Sum of digits:", total)
# Out:
# Enter a number:583
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_277/3058026337.py in <cell line: 0>()
#       1 number = int(input("Enter a number:"))
#       2 total = 0
# ----> 3 while number > 0:
#       4     digit = number % 10
#       5     number // 10
#
# KeyboardInterrupt:

# %%
from typing import OrderedDict
number = int(input("Enter a number:"))

original = number
reverse = 0

while number > 0:
  digit = number % 10
  reverse = reverse * 10 + digit
  number = number // 10

if original == reverse:
  print("Palindrome")
else:
  print("Not Palindrome")
# Out:
# Enter a number:123
# Not Palindrome

# %%
count = 0

for i in range (4,101,4):
  if i % 2 == 0:
    print(i)
    count = count + i

print("Sum:", count)
# Out:
# 4
# 8
# 12
# 16
# 20
# 24
# 28
# 32
# 36
# 40
# 44
# 48
# 52
# 56
# 60
# 64
# 68
# 72
# 76
# 80
# 84
# 88
# 92
# 96
# 100
# Sum: 1300

# %%
count = 0
number = 0

i = int(input("Enter i:"))

for i in range(1, i + 1):
  if i % 2 != 0:
      count = count + 1
      number = number + i

print("Sum:", count)
print(number)
# Out:
# Enter i:10
# Sum: 5
# 25

# %%
def my_function1():
  num1 = 10
  num2 = 20
  sum = num1 + num2
  print("Sum =",sum)

def my_function2():
  num1 = 30
  num2 = 40
  sum = num1 + num2
  print("Sum =",sum)

my_function1()
my_function2()
# Out:
# Sum = 30
# Sum = 70

# %%
def my_function(name):
  print(name)

my_function("Jem")
my_function("Som")
# Out:
# Jem
# Som
