# %% [markdown]
# <a href="https://colab.research.google.com/github/Shubham333231/Cursor-ai/blob/main/day1%20masai.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
age = 21
price = 480.76
name = "Student"
is_student = False

print(age, price, name, is_student)
# Out:
# 21 480.76 Student False

# %%
age = 21
price = 480.76
name = "34"
is_student = False

print(type(age))
print(type(price), type(name), type(is_student))
# Out:
# <class 'int'>
# <class 'float'> <class 'str'> <class 'bool'>

# %%
bill = 950
people = 4

print(bill/people)
print(bill//people)
print(bill>1000)
# Out:
# 237.5
# 237
# False

# %%
balance = 100
transaction_amount = 1000

if transaction_amount < balance:
  print("Transaction is not allowed")

else:
  print("Transaction is allowed")
# Out:
# Transaction is allowed

# %%
age = 22
has_valid_id = True

if age>=18 and has_valid_id:
  print("Entry Allowed")

else:
  print("Entry not Allowed")
# Out:
# Entry Allowed

# %%
is_weekend = False
is_holiday = True
is_blacklisted = False

if is_weekend or is_holiday:
    print("Store closes at 6 p.m.")
if not is_blacklisted:
    print("Transaction approved")
# Out:
# Store closes at 6 p.m.
# Transaction approved

# %%
cart_total = 501
is_prime_member = "Yes"
cart_total = float(cart_total)

if cart_total >= 1000 and is_prime_member == "yes":
  print("Free delivery:", True)

elif cart_total >= 500 or is_prime_member == "yes":
  print("Free delivery:", True)

else:
  print("Free delivery:", False)
# Out:
# Free delivery: True
