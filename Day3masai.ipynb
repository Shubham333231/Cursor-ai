# %% [markdown]
# <a href="https://colab.research.google.com/github/Shubham333231/Cursor-ai/blob/main/Day3masai.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
num = int(input("Enter a  number:"))

if num >= 0:
  print("The number is positive")

elif num <= 0:
  print("The number is negative")

elif num == 0:
  print("The number is zero")

else:
  print("Input is wrong")
# Out:
# Enter a  number:-7
# The number is negative

# %%
num_1 = int(input("Enter a number"))
num_2 = int(input("Enter a number"))

if num_1 >= num_2:
  print("The largest number is", num_1)

else:
  print("The largest number is", num_2)
# Out:
# Enter a number22
# Enter a number44
# The largest number is 44

# %%
Num_1 = 20
Num_2 = 45
Num_3 = 32

if Num_1 >= Num_2 and Num_3:
  print("The largest number is", Num_1)

elif Num_2 >= Num_1 and Num_3:
  print("The largest number is", Num_2)

else:
  print("The largest number is", Num_3)
# Out:
# The largest number is 45

# %%
from ast import Num
Num_1 = 20
Num_2 = 31
Num_3 = 32

if Num_1 >= Num_2 and Num_1 >= Num_3:
  print("The largest number is", Num_1)

elif Num_2 >= Num_1 and Num_2 >= Num_3:
  print("The largest number is", Num_2)

else:
  print("The largest number is", Num_3)
# Out:
# The largest number is 32

# %%
correct_username = str(input("Enter the username"))     #"admin"
correct_password = int(input("Enter the password"))  #"12345"

if correct_username == " admin"  and correct_password == 12345:
  print("Login successful")

else:
  print("Invalid username or password")
# Out:
# Enter the username admin
# Enter the password 12345
# Login successful

# %%
Marks = int(input("Enter your marks:"))

if Marks >= 90:
  print("Grade A")

elif Marks >= 75 and Marks <= 89:
  print("Grade B")

elif Marks >= 60 and Marks <= 74:
  print("Grade C")

elif Marks >= 40 and Marks <= 59:
  print("Grade D")

elif Marks <= 39 and Marks >= 35:
  print("Grade E")

else:
  print("Your Result is Fucked UP!")
# Out:
# Enter your marks:33
# Your Result is Fucked UP!

# %%
count = 5
while count >= 1:
  print(count)
  count = count - 1
# Out:
# 5
# 4
# 3
# 2
# 1

# %%
n = 5
total = 0
number = 1

while number <= n:
  total = total + number
  number = number + 1

print("Sum:", total)
# Out:
# Sum: 15

# %%
correct_password = "1234"
attempts = 0

while attempts < 3:
    password = input("Enter the password:")

    if password == correct_password:
        print("Login Successful")
        break
    else:
        print("Wrong Password")
        attempts += 1

if attempts == 3:
    print("Account Locked")
# Out:
# Enter the password:1111
# Wrong Password
# Enter the password:6666
# Wrong Password
# Enter the password:8888
# Wrong Password
# Account Locked

# %%
44
# Out:
# 44

# %%
balance = 1000
transaction_amount = float(input("Enter a ammount")) #1500

if transaction_amount <= balance:
  print("Payment Successfull")

elif transaction_amount >= balance:
  print("Insufficient Amount")

else:
  print("Server Error")
# Out:
# Enter a ammount1500
# Insufficient Amount
